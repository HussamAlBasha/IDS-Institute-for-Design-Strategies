# %% [markdown]
# <h1 style="color:#AED6F1 ; font-weight: bold; font-style: italic;">Loading Data</h1>
#
# Data can be loaded as normal using `pandas`' `read_csv()` or `read_excel()` functions.

# %%
# %load_ext autoreload
# %autoreload 2

# Add soundscapy to the Python path
# import sys
# sys.path.append('../..')
import soundscapy
import pandas as pd
df = pd.read_excel("Data-Test.xlsx", sheet_name="Tabelle1")
df
# Out:
#            LocationID           SessionID GroupID  RecordID Language  \
# 0          CamdenTown         CamdenTown1   CT101     525.0  English
# 1          CamdenTown         CamdenTown1   CT101     561.0  English
# 2          CamdenTown         CamdenTown1   CT101     526.0  English
# 3          CamdenTown         CamdenTown1   CT102     560.0  English
# 4          CamdenTown         CamdenTown1   CT103     527.0  English
# 5          CamdenTown         CamdenTown1   CT104     528.0  English
# 6          CamdenTown         CamdenTown1   CT105     555.0  English
# 7          CamdenTown         CamdenTown1   CT105     529.0  English
# 8          CamdenTown         CamdenTown1   CT106     530.0  English
# 9          CamdenTown         CamdenTown1   CT107     559.0  English
# 10          EustonTap          EustonTap4   ET401       NaN      NaN
# 11          EustonTap          EustonTap4   ET402       NaN      NaN
# 12          EustonTap          EustonTap4   ET403       NaN      NaN
# 13          EustonTap          EustonTap4   ET404       NaN      NaN
# 14          EustonTap          EustonTap4   ET405       NaN      NaN
# 15          EustonTap          EustonTap4   ET406       NaN      NaN
# 16          EustonTap          EustonTap4   ET407       NaN      NaN
# 17          EustonTap          EustonTap4   ET408       NaN      NaN
# 18          EustonTap          EustonTap4   ET409       NaN      NaN
# 19          EustonTap          EustonTap4   ET410       NaN      NaN
# 20       TorringtonSq       TorringtonSq5   TS532       NaN      NaN
# 21       TorringtonSq       TorringtonSq5   TS533       NaN      NaN
# 22       TorringtonSq       TorringtonSq5   TS534       NaN      NaN
# 23       TorringtonSq       TorringtonSq5   TS535       NaN      NaN
# 24       TorringtonSq       TorringtonSq5   TS536       NaN      NaN
# 25       TorringtonSq       TorringtonSq5   TS537       NaN      NaN
# 26       TorringtonSq       TorringtonSq5   TS538       NaN      NaN
# 27       TorringtonSq       TorringtonSq5   TS539       NaN      NaN
# 28       TorringtonSq       TorringtonSq5   TS540       NaN      NaN
# 29       TorringtonSq       TorringtonSq5   TS541       NaN      NaN
# 30         TateModern         TateModern3   TM321     748.0  English
# 31         TateModern         TateModern3   TM322     747.0  English
# 32         TateModern         TateModern3   TM323     777.0  English
# 33         TateModern         TateModern3   TM324     773.0  English
# 34         TateModern         TateModern3   TM324     749.0  English
# 35         TateModern         TateModern3   TM325     767.0  English
# 36         TateModern         TateModern3   TM325     772.0  English
# 37         TateModern         TateModern3   TM326     771.0  English
# 38         TateModern         TateModern3   TM327     751.0  English
# 39         TateModern         TateModern3   TM328     752.0  English
# 40  RegentsParkFields  RegentsParkFields1   RF116     815.0  English
# 41  RegentsParkFields  RegentsParkFields1   RF116     816.0  English
# 42  RegentsParkFields  RegentsParkFields1   RF116     814.0  English
# 43  RegentsParkFields  RegentsParkFields1   RF117     818.0  English
# 44  RegentsParkFields  RegentsParkFields1   RF117     817.0  English
# 45  RegentsParkFields  RegentsParkFields1   RF118     819.0  English
# 46  RegentsParkFields  RegentsParkFields1   RF119     820.0  English
# 47  RegentsParkFields  RegentsParkFields1   RF120     822.0  English
# 48  RegentsParkFields  RegentsParkFields1   RF120     821.0  English
# 49  RegentsParkFields  RegentsParkFields1   RF121     823.0  English
#
#     Lockdown          start_time            end_time   latitude  longitude  \
# 0          0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624
# 1          0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624
# 2          0 2019-05-02 11:41:00 2019-05-02 11:44:00  51.539124  -0.142624
# 3          0 2019-05-02 11:50:00 2019-05-02 11:53:00  51.539124  -0.142624
# 4          0 2019-05-02 11:49:00 2019-05-02 11:54:00  51.539124  -0.142624
# 5          0 2019-05-02 11:52:00 2019-05-02 12:03:00  51.539124  -0.142624
# 6          0 2019-05-02 11:56:00 2019-05-02 12:09:00  51.539124  -0.142624
# 7          0 2019-05-02 11:56:00 2019-05-02 12:09:00  51.539124  -0.142624
# 8          0 2019-05-02 12:07:00 2019-05-02 12:12:00  51.539124  -0.142624
# 9          0 2019-05-02 12:20:00 2019-05-02 12:25:00  51.539124  -0.142624
# 10         1                 NaT                 NaT        NaN        NaN
# 11         1                 NaT                 NaT        NaN        NaN
# 12         1                 NaT                 NaT        NaN        NaN
# 13         1                 NaT                 NaT        NaN        NaN
# 14         1                 NaT                 NaT        NaN        NaN
# 15         1                 NaT                 NaT        NaN        NaN
# 16         1                 NaT                 NaT        NaN        NaN
# 17         1                 NaT                 NaT        NaN        NaN
# 18         1                 NaT                 NaT        NaN        NaN
# 19         1                 NaT                 NaT        NaN        NaN
# 20         1                 NaT                 NaT        NaN        NaN
# 21         1                 NaT                 NaT        NaN        NaN
# 22         1                 NaT                 NaT        NaN        NaN
# 23         1                 NaT                 NaT        NaN        NaN
# 24         1                 NaT                 NaT        NaN        NaN
# 25         1                 NaT                 NaT        NaN        NaN
# 26         1                 NaT                 NaT        NaN        NaN
# 27         1                 NaT                 NaT        NaN        NaN
# 28         1                 NaT                 NaT        NaN        NaN
# 29         1                 NaT                 NaT        NaN        NaN
# 30         0 2019-05-24 12:10:00 2019-05-24 12:13:00  51.508484  -0.099861
# 31         0 2019-05-24 12:09:00 2019-05-24 12:11:00  51.508493  -0.099921
# 32         0 2019-05-24 12:18:00 2019-05-24 12:23:00  51.508444  -0.099866
# 33         0 2019-05-24 12:24:00 2019-05-24 12:39:00  51.508444  -0.099866
# 34         0 2019-05-24 12:20:00 2019-05-24 12:22:00  51.508483  -0.099884
# 35         0 2019-05-24 12:30:00 2019-05-24 12:37:00  51.508444  -0.099866
# 36         0 2019-05-24 12:30:00 2019-05-24 12:35:00  51.508444  -0.099866
# 37         0 2019-05-24 17:43:00 2019-05-24 12:46:00  51.508444  -0.099866
# 38         0 2019-05-24 12:47:00 2019-05-24 12:51:00  51.508409  -0.099869
# 39         0 2019-05-24 12:50:00 2019-05-24 12:55:00  51.508531  -0.099814
# 40         0 2019-05-31 12:22:00 2019-05-31 12:26:00  51.532535  -0.146275
# 41         0 2019-05-31 12:24:00 2019-05-31 12:26:00  51.530675  -0.149612
# 42         0 2019-05-31 11:22:00 2019-05-31 11:26:00  51.532535  -0.146275
# 43         0 2019-05-31 11:26:00 2019-05-31 11:30:00  51.530492  -0.146047
# 44         0 2019-05-31 11:27:00 2019-05-31 11:29:00  51.531420  -0.145995
# 45         0 2019-05-31 11:32:00 2019-05-31 11:35:00  51.532535  -0.146275
# 46         0 2019-05-31 12:35:00 2019-05-31 12:38:00  51.530675  -0.149612
# 47         0 2019-05-31 12:28:00 2019-05-31 12:37:00  51.532252  -0.146210
# 48         0 2019-05-31 11:28:00 2019-05-31 11:37:00  51.532535  -0.146275
# 49         0 2019-05-31 11:38:00 2019-05-31 11:39:00  51.532535  -0.146275
#
#     ...  FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 0   ...              0.01700               0.358                   0.3090
# 1   ...              0.01700               0.358                   0.3090
# 2   ...              0.01700               0.358                   0.3090
# 3   ...              0.01790               0.362                   0.2680
# 4   ...              0.00889               0.370                   0.1930
# 5   ...              0.01460               0.393                   0.2100
# 6   ...                  NaN                 NaN                      NaN
# 7   ...                  NaN                 NaN                      NaN
# 8   ...                  NaN                 NaN                      NaN
# 9   ...              0.02470               0.426                   0.2930
# 10  ...              0.00524               0.333                   0.1150
# 11  ...              0.00484               0.335                   0.1260
# 12  ...              0.00417               0.310                   0.1190
# 13  ...              0.00532               0.293                   0.1590
# 14  ...              0.00449               0.308                   0.1250
# 15  ...              0.00717               0.330                   0.2300
# 16  ...              0.00481               0.316                   0.1650
# 17  ...              0.00364               0.311                   0.0649
# 18  ...              0.00537               0.315                   0.1720
# 19  ...              0.00449               0.284                   0.3590
# 20  ...              0.00902               0.320                   0.3280
# 21  ...              0.00560               0.351                   0.1170
# 22  ...              0.00375               0.418                   0.0960
# 23  ...              0.01190               0.466                   0.2390
# 24  ...              0.01080               0.509                   0.2160
# 25  ...              0.00550               0.399                   0.2030
# 26  ...              0.00916               0.359                   0.2300
# 27  ...              0.00967               0.363                   0.4810
# 28  ...              0.00902               0.445                   0.2570
# 29  ...              0.00930               0.404                   0.2460
# 30  ...              0.02100               0.403                   0.2970
# 31  ...                  NaN                 NaN                      NaN
# 32  ...                  NaN                 NaN                      NaN
# 33  ...                  NaN                 NaN                      NaN
# 34  ...                  NaN                 NaN                      NaN
# 35  ...              0.06440               0.437                   0.8510
# 36  ...              0.06440               0.437                   0.8510
# 37  ...              0.02330               0.406                   0.2510
# 38  ...              0.01710               0.482                   0.3510
# 39  ...              0.04290               0.439                   0.2870
# 40  ...              0.01650               0.439                   0.1210
# 41  ...              0.01650               0.439                   0.1210
# 42  ...              0.01650               0.439                   0.1210
# 43  ...              0.01410               0.427                   0.1270
# 44  ...              0.01410               0.427                   0.1270
# 45  ...              0.02270               0.495                   0.0940
# 46  ...                  NaN                 NaN                      NaN
# 47  ...              0.02720               0.413                   0.0957
# 48  ...              0.02720               0.413                   0.0957
# 49  ...              0.03400               0.420                   0.1360
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 0             79.72               70.07                7.78
# 1             79.72               70.07                7.78
# 2             79.72               70.07                7.78
# 3             80.27               71.26                8.38
# 4             76.79               66.71                4.23
# 5             80.13               72.47                6.97
# 6               NaN                 NaN                 NaN
# 7               NaN                 NaN                 NaN
# 8               NaN                 NaN                 NaN
# 9             78.52               68.32                8.55
# 10            76.84               69.23                6.23
# 11            69.57               62.97               10.36
# 12            75.83               66.83                8.26
# 13            71.32               58.56                2.64
# 14            75.01               66.89                3.93
# 15            79.31               59.79                4.39
# 16            77.07               68.41                6.58
# 17            69.48               59.59                7.24
# 18            78.22               69.98               16.48
# 19            76.49               64.31               13.06
# 20            67.18               55.15                5.12
# 21            70.54               57.12               11.36
# 22            68.70               57.04               10.80
# 23            71.71               60.35               10.31
# 24            79.78               55.54                8.41
# 25            71.77               52.90                5.61
# 26            68.85               56.30               10.09
# 27            79.33               64.32               14.80
# 28            67.57               49.33                2.64
# 29            78.01               59.17               16.54
# 30            79.03               66.27                6.82
# 31              NaN                 NaN                 NaN
# 32              NaN                 NaN                 NaN
# 33              NaN                 NaN                 NaN
# 34              NaN                 NaN                 NaN
# 35            79.34               74.18               11.73
# 36            79.34               74.18               11.73
# 37            73.51               62.61                5.64
# 38            77.64               63.79                5.11
# 39            73.59               64.11                7.89
# 40            79.93               66.07                5.27
# 41            79.93               66.07                5.27
# 42            79.93               66.07                5.27
# 43            76.38               63.10                5.53
# 44            76.38               63.10                5.53
# 45            65.12               51.21                4.44
# 46              NaN                 NaN                 NaN
# 47            73.82               54.54                9.07
# 48            73.82               54.54                9.07
# 49            71.75               55.87                8.21
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 0                 7.81                8.11          14.30    36.019181
# 1                 7.81                8.11          14.30    36.019181
# 2                 7.81                8.11          14.30    36.019181
# 3                 6.25                7.82          14.70    40.523268
# 4                 7.61                3.99          13.40    27.108635
# 5                 6.32                3.79          15.10    48.708825
# 6                  NaN                 NaN            NaN          NaN
# 7                  NaN                 NaN            NaN          NaN
# 8                  NaN                 NaN            NaN          NaN
# 9                 8.00                5.60          14.80    32.959376
# 10                6.68                5.51          12.60    41.381249
# 11                5.02                6.32          10.70    34.366650
# 12                5.84                7.11          12.10    34.366650
# 13               10.71                3.45          11.20    34.366650
# 14                6.34                3.77          12.40    38.822900
# 15               13.60                7.84          13.30          NaN
# 16                6.89                5.25          12.90          NaN
# 17                7.70                4.17          10.80    38.846366
# 18                6.16               12.28          12.50    38.846366
# 19               10.50               11.12          11.30    37.989434
# 20                8.39                4.26           8.97    37.989434
# 21                9.88               11.43          10.20    27.090436
# 22                7.96               10.54           9.97          NaN
# 23                8.38                7.81          10.70          NaN
# 24               16.14               10.92          12.80    46.548897
# 25               12.97                8.31          10.80    46.548897
# 26                9.27                8.16           9.99    36.548457
# 27               13.95               20.39          10.90    36.548457
# 28               12.12                5.04           9.62          NaN
# 29               14.17               17.02          11.10          NaN
# 30                9.73                4.79          15.20    29.868333
# 31                 NaN                 NaN            NaN    48.581586
# 32                 NaN                 NaN            NaN    35.780862
# 33                 NaN                 NaN            NaN    48.207210
# 34                 NaN                 NaN            NaN    40.585995
# 35                1.43                8.38          16.60    32.011822
# 36                1.43                8.38          16.60    32.011822
# 37                9.46                3.19          13.30    30.767981
# 38               11.46                3.63          13.80    30.767981
# 39                6.50                4.23          14.20    49.281216
# 40                9.44                3.49          13.30    49.281216
# 41                9.44                3.49          13.30    33.313603
# 42                9.44                3.49          13.30    33.313603
# 43                9.82                3.25          13.10          NaN
# 44                9.82                3.25          13.10          NaN
# 45                9.78                3.96          10.80    35.027791
# 46                 NaN                 NaN            NaN          NaN
# 47               11.98                5.70          10.90          NaN
# 48               11.98                5.70          10.90          NaN
# 49                9.66                8.91          12.30   100.494469
#
# [50 rows x 78 columns]

# %% [markdown]
# <h1 style="color:#AED6F1 ; font-weight: bold; font-style: italic;">Filtering Data</h1>
#
# The ISD includes survey data and the accompanying acoustic data collected from respondents *in situ* in 13 urban locations in London and Venice. It also include recording-only data taken during the COVID-19 lockdowns in 2020. Since for this example we'll only be looking at survey data, we can start by filtering out the lockdown data.
#
# This is done using a method included in the `isd` `pandas` namespace.

# %%
df = df.isd.filter_lockdown()
df.shape
# Out:
# (30, 78)

# %% [markdown]
# <h1 style="color:#AED6F1 ; font-weight: bold; font-style: italic;">Validating the Dataset</h1>
#
# In order to validate that the dataset includes the data we would expect, and to check for missing or incorrect PAQ data, we use the `validate_dataset()` method. This method can also rename the PAQ columns if necessary.

# %%
#from soundscapy.databases import isd
df, excl = df.isd.validate_dataset()
df
# Out:
# Renaming PAQ columns.
# Checking PAQ data quality.
# PAQ quality confirmed. No rows dropped.
#            LocationID           SessionID GroupID  RecordID Language  \
# 0          CamdenTown         CamdenTown1   CT101     525.0  English
# 1          CamdenTown         CamdenTown1   CT101     561.0  English
# 2          CamdenTown         CamdenTown1   CT101     526.0  English
# 3          CamdenTown         CamdenTown1   CT102     560.0  English
# 4          CamdenTown         CamdenTown1   CT103     527.0  English
# 5          CamdenTown         CamdenTown1   CT104     528.0  English
# 6          CamdenTown         CamdenTown1   CT105     555.0  English
# 7          CamdenTown         CamdenTown1   CT105     529.0  English
# 8          CamdenTown         CamdenTown1   CT106     530.0  English
# 9          CamdenTown         CamdenTown1   CT107     559.0  English
# 30         TateModern         TateModern3   TM321     748.0  English
# 31         TateModern         TateModern3   TM322     747.0  English
# 32         TateModern         TateModern3   TM323     777.0  English
# 33         TateModern         TateModern3   TM324     773.0  English
# 34         TateModern         TateModern3   TM324     749.0  English
# 35         TateModern         TateModern3   TM325     767.0  English
# 36         TateModern         TateModern3   TM325     772.0  English
# 37         TateModern         TateModern3   TM326     771.0  English
# 38         TateModern         TateModern3   TM327     751.0  English
# 39         TateModern         TateModern3   TM328     752.0  English
# 40  RegentsParkFields  RegentsParkFields1   RF116     815.0  English
# 41  RegentsParkFields  RegentsParkFields1   RF116     816.0  English
# 42  RegentsParkFields  RegentsParkFields1   RF116     814.0  English
# 43  RegentsParkFields  RegentsParkFields1   RF117     818.0  English
# 44  RegentsParkFields  RegentsParkFields1   RF117     817.0  English
# 45  RegentsParkFields  RegentsParkFields1   RF118     819.0  English
# 46  RegentsParkFields  RegentsParkFields1   RF119     820.0  English
# 47  RegentsParkFields  RegentsParkFields1   RF120     822.0  English
# 48  RegentsParkFields  RegentsParkFields1   RF120     821.0  English
# 49  RegentsParkFields  RegentsParkFields1   RF121     823.0  English
#
#     Lockdown          start_time            end_time   latitude  longitude  \
# 0          0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624
# 1          0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624
# 2          0 2019-05-02 11:41:00 2019-05-02 11:44:00  51.539124  -0.142624
# 3          0 2019-05-02 11:50:00 2019-05-02 11:53:00  51.539124  -0.142624
# 4          0 2019-05-02 11:49:00 2019-05-02 11:54:00  51.539124  -0.142624
# 5          0 2019-05-02 11:52:00 2019-05-02 12:03:00  51.539124  -0.142624
# 6          0 2019-05-02 11:56:00 2019-05-02 12:09:00  51.539124  -0.142624
# 7          0 2019-05-02 11:56:00 2019-05-02 12:09:00  51.539124  -0.142624
# 8          0 2019-05-02 12:07:00 2019-05-02 12:12:00  51.539124  -0.142624
# 9          0 2019-05-02 12:20:00 2019-05-02 12:25:00  51.539124  -0.142624
# 30         0 2019-05-24 12:10:00 2019-05-24 12:13:00  51.508484  -0.099861
# 31         0 2019-05-24 12:09:00 2019-05-24 12:11:00  51.508493  -0.099921
# 32         0 2019-05-24 12:18:00 2019-05-24 12:23:00  51.508444  -0.099866
# 33         0 2019-05-24 12:24:00 2019-05-24 12:39:00  51.508444  -0.099866
# 34         0 2019-05-24 12:20:00 2019-05-24 12:22:00  51.508483  -0.099884
# 35         0 2019-05-24 12:30:00 2019-05-24 12:37:00  51.508444  -0.099866
# 36         0 2019-05-24 12:30:00 2019-05-24 12:35:00  51.508444  -0.099866
# 37         0 2019-05-24 17:43:00 2019-05-24 12:46:00  51.508444  -0.099866
# 38         0 2019-05-24 12:47:00 2019-05-24 12:51:00  51.508409  -0.099869
# 39         0 2019-05-24 12:50:00 2019-05-24 12:55:00  51.508531  -0.099814
# 40         0 2019-05-31 12:22:00 2019-05-31 12:26:00  51.532535  -0.146275
# 41         0 2019-05-31 12:24:00 2019-05-31 12:26:00  51.530675  -0.149612
# 42         0 2019-05-31 11:22:00 2019-05-31 11:26:00  51.532535  -0.146275
# 43         0 2019-05-31 11:26:00 2019-05-31 11:30:00  51.530492  -0.146047
# 44         0 2019-05-31 11:27:00 2019-05-31 11:29:00  51.531420  -0.145995
# 45         0 2019-05-31 11:32:00 2019-05-31 11:35:00  51.532535  -0.146275
# 46         0 2019-05-31 12:35:00 2019-05-31 12:38:00  51.530675  -0.149612
# 47         0 2019-05-31 12:28:00 2019-05-31 12:37:00  51.532252  -0.146210
# 48         0 2019-05-31 11:28:00 2019-05-31 11:37:00  51.532535  -0.146275
# 49         0 2019-05-31 11:38:00 2019-05-31 11:39:00  51.532535  -0.146275
#
#     ...  FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 0   ...              0.01700               0.358                   0.3090
# 1   ...              0.01700               0.358                   0.3090
# 2   ...              0.01700               0.358                   0.3090
# 3   ...              0.01790               0.362                   0.2680
# 4   ...              0.00889               0.370                   0.1930
# 5   ...              0.01460               0.393                   0.2100
# 6   ...                  NaN                 NaN                      NaN
# 7   ...                  NaN                 NaN                      NaN
# 8   ...                  NaN                 NaN                      NaN
# 9   ...              0.02470               0.426                   0.2930
# 30  ...              0.02100               0.403                   0.2970
# 31  ...                  NaN                 NaN                      NaN
# 32  ...                  NaN                 NaN                      NaN
# 33  ...                  NaN                 NaN                      NaN
# 34  ...                  NaN                 NaN                      NaN
# 35  ...              0.06440               0.437                   0.8510
# 36  ...              0.06440               0.437                   0.8510
# 37  ...              0.02330               0.406                   0.2510
# 38  ...              0.01710               0.482                   0.3510
# 39  ...              0.04290               0.439                   0.2870
# 40  ...              0.01650               0.439                   0.1210
# 41  ...              0.01650               0.439                   0.1210
# 42  ...              0.01650               0.439                   0.1210
# 43  ...              0.01410               0.427                   0.1270
# 44  ...              0.01410               0.427                   0.1270
# 45  ...              0.02270               0.495                   0.0940
# 46  ...                  NaN                 NaN                      NaN
# 47  ...              0.02720               0.413                   0.0957
# 48  ...              0.02720               0.413                   0.0957
# 49  ...              0.03400               0.420                   0.1360
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 0             79.72               70.07                7.78
# 1             79.72               70.07                7.78
# 2             79.72               70.07                7.78
# 3             80.27               71.26                8.38
# 4             76.79               66.71                4.23
# 5             80.13               72.47                6.97
# 6               NaN                 NaN                 NaN
# 7               NaN                 NaN                 NaN
# 8               NaN                 NaN                 NaN
# 9             78.52               68.32                8.55
# 30            79.03               66.27                6.82
# 31              NaN                 NaN                 NaN
# 32              NaN                 NaN                 NaN
# 33              NaN                 NaN                 NaN
# 34              NaN                 NaN                 NaN
# 35            79.34               74.18               11.73
# 36            79.34               74.18               11.73
# 37            73.51               62.61                5.64
# 38            77.64               63.79                5.11
# 39            73.59               64.11                7.89
# 40            79.93               66.07                5.27
# 41            79.93               66.07                5.27
# 42            79.93               66.07                5.27
# 43            76.38               63.10                5.53
# 44            76.38               63.10                5.53
# 45            65.12               51.21                4.44
# 46              NaN                 NaN                 NaN
# 47            73.82               54.54                9.07
# 48            73.82               54.54                9.07
# 49            71.75               55.87                8.21
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 0                 7.81                8.11           14.3    36.019181
# 1                 7.81                8.11           14.3    36.019181
# 2                 7.81                8.11           14.3    36.019181
# 3                 6.25                7.82           14.7    40.523268
# 4                 7.61                3.99           13.4    27.108635
# 5                 6.32                3.79           15.1    48.708825
# 6                  NaN                 NaN            NaN          NaN
# 7                  NaN                 NaN            NaN          NaN
# 8                  NaN                 NaN            NaN          NaN
# 9                 8.00                5.60           14.8    32.959376
# 30                9.73                4.79           15.2    29.868333
# 31                 NaN                 NaN            NaN    48.581586
# 32                 NaN                 NaN            NaN    35.780862
# 33                 NaN                 NaN            NaN    48.207210
# 34                 NaN                 NaN            NaN    40.585995
# 35                1.43                8.38           16.6    32.011822
# 36                1.43                8.38           16.6    32.011822
# 37                9.46                3.19           13.3    30.767981
# 38               11.46                3.63           13.8    30.767981
# 39                6.50                4.23           14.2    49.281216
# 40                9.44                3.49           13.3    49.281216
# 41                9.44                3.49           13.3    33.313603
# 42                9.44                3.49           13.3    33.313603
# 43                9.82                3.25           13.1          NaN
# 44                9.82                3.25           13.1          NaN
# 45                9.78                3.96           10.8    35.027791
# 46                 NaN                 NaN            NaN          NaN
# 47               11.98                5.70           10.9          NaN
# 48               11.98                5.70           10.9          NaN
# 49                9.66                8.91           12.3   100.494469
#
# [30 rows x 78 columns]

# %% [markdown]
# <h1 style="color:#AED6F1 ; font-weight: bold; font-style: italic;">Calculating the ISOPleasant and ISOEventful Coordinate Values</h1>
#
# Start by returning a version of the dataset which only includes the PAQs so we won't conflict with the pre-computed ISOCoordinate values.

# %%
paqs = df.sspy.return_paqs()
paqs
# Out:
#     RecordID GroupID           SessionID         LocationID  PAQ1  PAQ2  PAQ3  \
# 0      525.0   CT101         CamdenTown1         CamdenTown   2.0   3.0   4.0
# 1      561.0   CT101         CamdenTown1         CamdenTown   3.0   2.0   2.0
# 2      526.0   CT101         CamdenTown1         CamdenTown   4.0   3.0   3.0
# 3      560.0   CT102         CamdenTown1         CamdenTown   4.0   2.0   2.0
# 4      527.0   CT103         CamdenTown1         CamdenTown   3.0   5.0   4.0
# 5      528.0   CT104         CamdenTown1         CamdenTown   2.0   5.0   4.0
# 6      555.0   CT105         CamdenTown1         CamdenTown   3.0   3.0   2.0
# 7      529.0   CT105         CamdenTown1         CamdenTown   4.0   4.0   4.0
# 8      530.0   CT106         CamdenTown1         CamdenTown   2.0   4.0   2.0
# 9      559.0   CT107         CamdenTown1         CamdenTown   4.0   4.0   3.0
# 30     748.0   TM321         TateModern3         TateModern   5.0   3.0   4.0
# 31     747.0   TM322         TateModern3         TateModern   4.0   4.0   4.0
# 32     777.0   TM323         TateModern3         TateModern   5.0   5.0   5.0
# 33     773.0   TM324         TateModern3         TateModern   5.0   4.0   2.0
# 34     749.0   TM324         TateModern3         TateModern   4.0   5.0   4.0
# 35     767.0   TM325         TateModern3         TateModern   4.0   5.0   3.0
# 36     772.0   TM325         TateModern3         TateModern   4.0   4.0   4.0
# 37     771.0   TM326         TateModern3         TateModern   4.0   4.0   4.0
# 38     751.0   TM327         TateModern3         TateModern   4.0   2.0   4.0
# 39     752.0   TM328         TateModern3         TateModern   4.0   4.0   5.0
# 40     815.0   RF116  RegentsParkFields1  RegentsParkFields   3.0   3.0   3.0
# 41     816.0   RF116  RegentsParkFields1  RegentsParkFields   1.0   1.0   5.0
# 42     814.0   RF116  RegentsParkFields1  RegentsParkFields   1.0   4.0   3.0
# 43     818.0   RF117  RegentsParkFields1  RegentsParkFields   5.0   5.0   2.0
# 44     817.0   RF117  RegentsParkFields1  RegentsParkFields   5.0   3.0   1.0
# 45     819.0   RF118  RegentsParkFields1  RegentsParkFields   4.0   1.0   2.0
# 46     820.0   RF119  RegentsParkFields1  RegentsParkFields   4.0   3.0   2.0
# 47     822.0   RF120  RegentsParkFields1  RegentsParkFields   4.0   4.0   2.0
# 48     821.0   RF120  RegentsParkFields1  RegentsParkFields   4.0   4.0   4.0
# 49     823.0   RF121  RegentsParkFields1  RegentsParkFields   5.0   3.0   2.0
#
#     PAQ4  PAQ5  PAQ6  PAQ7  PAQ8
# 0    4.0   2.0   3.0   2.0   1.0
# 1    4.0   4.0   4.0   1.0   1.0
# 2    3.0   4.0   2.0   2.0   2.0
# 3    2.0   3.0   5.0   5.0   5.0
# 4    4.0   2.0   1.0   1.0   2.0
# 5    4.0   2.0   2.0   1.0   2.0
# 6    1.0   3.0   2.0   5.0   5.0
# 7    5.0   3.0   3.0   2.0   2.0
# 8    4.0   4.0   2.0   4.0   2.0
# 9    4.0   4.0   1.0   3.0   2.0
# 30   2.0   2.0   2.0   2.0   5.0
# 31   2.0   2.0   1.0   2.0   4.0
# 32   1.0   1.0   1.0   1.0   5.0
# 33   2.0   1.0   1.0   4.0   4.0
# 34   4.0   2.0   2.0   1.0   2.0
# 35   4.0   3.0   1.0   1.0   2.0
# 36   4.0   2.0   1.0   1.0   4.0
# 37   3.0   4.0   2.0   2.0   2.0
# 38   4.0   1.0   2.0   3.0   4.0
# 39   2.0   2.0   3.0   3.0   3.0
# 40   2.0   3.0   3.0   2.0   4.0
# 41   5.0   5.0   5.0   1.0   1.0
# 42   5.0   5.0   2.0   3.0   2.0
# 43   1.0   1.0   1.0   2.0   5.0
# 44   1.0   1.0   1.0   5.0   5.0
# 45   2.0   2.0   1.0   2.0   5.0
# 46   1.0   1.0   3.0   3.0   4.0
# 47   1.0   1.0   2.0   4.0   5.0
# 48   3.0   3.0   3.0   3.0   3.0
# 49   1.0   1.0   1.0   3.0   5.0

# %% [markdown]
# Now, calculate the ISOCoordinate values.

# %%
paqs = paqs.sspy.add_paq_coords()
paqs
# Out:
#     RecordID GroupID           SessionID         LocationID  PAQ1  PAQ2  PAQ3  \
# 0      525.0   CT101         CamdenTown1         CamdenTown   2.0   3.0   4.0
# 1      561.0   CT101         CamdenTown1         CamdenTown   3.0   2.0   2.0
# 2      526.0   CT101         CamdenTown1         CamdenTown   4.0   3.0   3.0
# 3      560.0   CT102         CamdenTown1         CamdenTown   4.0   2.0   2.0
# 4      527.0   CT103         CamdenTown1         CamdenTown   3.0   5.0   4.0
# 5      528.0   CT104         CamdenTown1         CamdenTown   2.0   5.0   4.0
# 6      555.0   CT105         CamdenTown1         CamdenTown   3.0   3.0   2.0
# 7      529.0   CT105         CamdenTown1         CamdenTown   4.0   4.0   4.0
# 8      530.0   CT106         CamdenTown1         CamdenTown   2.0   4.0   2.0
# 9      559.0   CT107         CamdenTown1         CamdenTown   4.0   4.0   3.0
# 30     748.0   TM321         TateModern3         TateModern   5.0   3.0   4.0
# 31     747.0   TM322         TateModern3         TateModern   4.0   4.0   4.0
# 32     777.0   TM323         TateModern3         TateModern   5.0   5.0   5.0
# 33     773.0   TM324         TateModern3         TateModern   5.0   4.0   2.0
# 34     749.0   TM324         TateModern3         TateModern   4.0   5.0   4.0
# 35     767.0   TM325         TateModern3         TateModern   4.0   5.0   3.0
# 36     772.0   TM325         TateModern3         TateModern   4.0   4.0   4.0
# 37     771.0   TM326         TateModern3         TateModern   4.0   4.0   4.0
# 38     751.0   TM327         TateModern3         TateModern   4.0   2.0   4.0
# 39     752.0   TM328         TateModern3         TateModern   4.0   4.0   5.0
# 40     815.0   RF116  RegentsParkFields1  RegentsParkFields   3.0   3.0   3.0
# 41     816.0   RF116  RegentsParkFields1  RegentsParkFields   1.0   1.0   5.0
# 42     814.0   RF116  RegentsParkFields1  RegentsParkFields   1.0   4.0   3.0
# 43     818.0   RF117  RegentsParkFields1  RegentsParkFields   5.0   5.0   2.0
# 44     817.0   RF117  RegentsParkFields1  RegentsParkFields   5.0   3.0   1.0
# 45     819.0   RF118  RegentsParkFields1  RegentsParkFields   4.0   1.0   2.0
# 46     820.0   RF119  RegentsParkFields1  RegentsParkFields   4.0   3.0   2.0
# 47     822.0   RF120  RegentsParkFields1  RegentsParkFields   4.0   4.0   2.0
# 48     821.0   RF120  RegentsParkFields1  RegentsParkFields   4.0   4.0   4.0
# 49     823.0   RF121  RegentsParkFields1  RegentsParkFields   5.0   3.0   2.0
#
#     PAQ4  PAQ5  PAQ6  PAQ7  PAQ8  ISOPleasant  ISOEventful
# 0    4.0   2.0   3.0   2.0   1.0    -0.219670     0.426777
# 1    4.0   4.0   4.0   1.0   1.0    -0.469670     0.176777
# 2    3.0   4.0   2.0   2.0   2.0     0.000000     0.250000
# 3    2.0   3.0   5.0   5.0   5.0     0.103553    -0.750000
# 4    4.0   2.0   1.0   1.0   2.0     0.250000     0.750000
# 5    4.0   2.0   2.0   1.0   2.0     0.073223     0.676777
# 6    1.0   3.0   2.0   5.0   5.0     0.366117    -0.530330
# 7    5.0   3.0   3.0   2.0   2.0    -0.042893     0.500000
# 8    4.0   4.0   2.0   4.0   2.0    -0.207107     0.085786
# 9    4.0   4.0   1.0   3.0   2.0     0.073223     0.366117
# 30   2.0   2.0   2.0   2.0   5.0     0.603553     0.060660
# 31   2.0   2.0   1.0   2.0   4.0     0.573223     0.280330
# 32   1.0   1.0   1.0   1.0   5.0     1.000000     0.414214
# 33   2.0   1.0   1.0   4.0   4.0     0.780330    -0.133883
# 34   4.0   2.0   2.0   1.0   2.0     0.280330     0.676777
# 35   4.0   3.0   1.0   1.0   2.0     0.250000     0.646447
# 36   4.0   2.0   1.0   1.0   4.0     0.426777     0.530330
# 37   3.0   4.0   2.0   2.0   2.0     0.073223     0.426777
# 38   4.0   1.0   2.0   3.0   4.0     0.310660     0.103553
# 39   2.0   2.0   3.0   3.0   3.0     0.353553     0.207107
# 40   2.0   3.0   3.0   2.0   4.0     0.146447    -0.042893
# 41   5.0   5.0   5.0   1.0   1.0    -1.000000     0.414214
# 42   5.0   5.0   2.0   3.0   2.0    -0.487437     0.366117
# 43   1.0   1.0   1.0   2.0   5.0     1.000000     0.000000
# 44   1.0   1.0   1.0   5.0   5.0     0.853553    -0.560660
# 45   2.0   2.0   1.0   2.0   5.0     0.426777    -0.219670
# 46   1.0   1.0   3.0   3.0   4.0     0.530330    -0.323223
# 47   1.0   1.0   2.0   4.0   5.0     0.750000    -0.353553
# 48   3.0   3.0   3.0   3.0   3.0     0.176777     0.176777
# 49   1.0   1.0   1.0   3.0   5.0     0.853553    -0.250000

# %% [markdown]
# `Soundscapy` expects the PAQ values to be Likert scale values ranging from 1 to 5 by default, as specified in ISO 12913 and the SSID Protocol. In example below it is not the case and that is why ISOCoordinates are not from -1 to +1

# %%
import pandas as pd
# By default it is from 1 to 5
val_range = (0, 100)
sample_transform = {
    "RecordID": ["EX1", "EX2"],
    "pleasant": [40, 25],
    "vibrant": [45, 31],
    "eventful": [41, 54],
    "chaotic": [24, 56],
    "annoying": [8, 52],
    "monotonous": [31, 55],
    "uneventful": [37, 31],
    "calm": [40, 10],
}

sample_transform = pd.DataFrame().from_dict(sample_transform)
sample_transform, excl = sample_transform.sspy.validate_dataset(val_range=val_range)
sample_transform = sample_transform.sspy.add_paq_coords()
sample_transform
# Out:
# Renaming PAQ columns.
# Checking PAQ data quality.
# PAQ quality confirmed. No rows dropped.
#   RecordID  PAQ1  PAQ2  PAQ3  PAQ4  PAQ5  PAQ6  PAQ7  PAQ8  ISOPleasant  \
# 0      EX1    40    45    41    24     8    31    37    40     5.510408
# 1      EX2    25    31    54    56    52    55    31    10    -7.921573
#
#    ISOEventful
# 0     0.267767
# 1     3.992641

# %% [markdown]
# `Soundscapy` expects the PAQ values to be Likert scale values ranging from 1 to 5 by default, as specified in ISO 12913 and the SSID Protocol. However, it is possible to use data which, although structured the same way, has a different range of values. For instance this could be a 7-point Likert scale, or a 0 to 100 scale. By passing these numbers both to `validate_dataset()` and `add_paq_coords()` as the `val_range`, `Soundscapy` will check that the data conforms to what is expected and will automatically scale the ISOCoordinates from -1 to +1 depending on the original value range.
#
# For example:

# %%
import pandas as pd
val_range = (0, 100)
sample_transform = {
    "RecordID": ["EX1", "EX2"],
    "pleasant": [40, 25],
    "vibrant": [45, 31],
    "eventful": [41, 54],
    "chaotic": [24, 56],
    "annoying": [8, 52],
    "monotonous": [31, 55],
    "uneventful": [37, 31],
    "calm": [40, 10],
}
sample_transform = pd.DataFrame().from_dict(sample_transform)
sample_transform, excl = sample_transform.sspy.validate_dataset(val_range=val_range)
sample_transform = sample_transform.sspy.add_paq_coords(val_range=val_range)
sample_transform
# Out:
# Renaming PAQ columns.
# Checking PAQ data quality.
# PAQ quality confirmed. No rows dropped.
#   RecordID  PAQ1  PAQ2  PAQ3  PAQ4  PAQ5  PAQ6  PAQ7  PAQ8  ISOPleasant  \
# 0      EX1    40    45    41    24     8    31    37    40     0.220416
# 1      EX2    25    31    54    56    52    55    31    10    -0.316863
#
#    ISOEventful
# 0     0.010711
# 1     0.159706

# %% [markdown]
# <h1 style="color:#AED6F1 ; font-weight: bold; font-style: italic;">More Filtering</h1>
#
# `Soundscapy` includes methods for several filters that are normally needed.
#
# #### Filtering by `LocationID`.

# %%
df = pd.read_excel("C:\\Users\\fspintern1\\Desktop\\Data-Test.xlsx", sheet_name="Tabelle1")
df.isd.filter_location_ids(['EustonTap']).head()
# Out:
#    LocationID   SessionID GroupID  RecordID Language  Lockdown start_time  \
# 10  EustonTap  EustonTap4   ET401       NaN      NaN         1        NaT
# 11  EustonTap  EustonTap4   ET402       NaN      NaN         1        NaT
# 12  EustonTap  EustonTap4   ET403       NaN      NaN         1        NaT
# 13  EustonTap  EustonTap4   ET404       NaN      NaN         1        NaT
# 14  EustonTap  EustonTap4   ET405       NaN      NaN         1        NaT
#
#    end_time  latitude  longitude  ...  FS_Avg,arith(vacil)  \
# 10      NaT       NaN        NaN  ...              0.00524
# 11      NaT       NaN        NaN  ...              0.00484
# 12      NaT       NaN        NaN  ...              0.00417
# 13      NaT       NaN        NaN  ...              0.00532
# 14      NaT       NaN        NaN  ...              0.00449
#
#     I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  LZeq_L(dB(SPL))  \
# 10               0.333                    0.115            76.84
# 11               0.335                    0.126            69.57
# 12               0.310                    0.119            75.83
# 13               0.293                    0.159            71.32
# 14               0.308                    0.125            75.01
#
#     LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  LCeq_LAeq(dB(SPL))  \
# 10               69.23                6.23                6.68
# 11               62.97               10.36                5.02
# 12               66.83                8.26                5.84
# 13               58.56                2.64               10.71
# 14               66.89                3.93                6.34
#
#     LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 10                5.51           12.6    41.381249
# 11                6.32           10.7    34.366650
# 12                7.11           12.1    34.366650
# 13                3.45           11.2    34.366650
# 14                3.77           12.4    38.822900
#
# [5 rows x 78 columns]

# %% [markdown]
# #### Filtering by `SessionID`.

# %%
df = pd.read_excel("C:\\Users\\fspintern1\\Desktop\\Data-Test.xlsx", sheet_name="Tabelle1")
df.isd.filter_session_ids(['CamdenTown1']).head(3)
# Out:
#    LocationID    SessionID GroupID  RecordID Language  Lockdown  \
# 0  CamdenTown  CamdenTown1   CT101     525.0  English         0
# 1  CamdenTown  CamdenTown1   CT101     561.0  English         0
# 2  CamdenTown  CamdenTown1   CT101     526.0  English         0
#
#            start_time            end_time   latitude  longitude  ...  \
# 0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624  ...
# 1 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624  ...
# 2 2019-05-02 11:41:00 2019-05-02 11:44:00  51.539124  -0.142624  ...
#
#    FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 0                0.017               0.358                    0.309
# 1                0.017               0.358                    0.309
# 2                0.017               0.358                    0.309
#
#    LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 0            79.72               70.07                7.78
# 1            79.72               70.07                7.78
# 2            79.72               70.07                7.78
#
#    LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 0                7.81                8.11           14.3    36.019181
# 1                7.81                8.11           14.3    36.019181
# 2                7.81                8.11           14.3    36.019181
#
# [3 rows x 78 columns]

# %% [markdown]
# #### Filtering by `GroupID`.

# %%
df.isd.filter_group_ids(['ET402'])
# Out:
#    LocationID   SessionID GroupID  RecordID Language  Lockdown start_time  \
# 11  EustonTap  EustonTap4   ET402       NaN      NaN         1        NaT
#
#    end_time  latitude  longitude  ...  FS_Avg,arith(vacil)  \
# 11      NaT       NaN        NaN  ...              0.00484
#
#     I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  LZeq_L(dB(SPL))  \
# 11               0.335                    0.126            69.57
#
#     LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  LCeq_LAeq(dB(SPL))  \
# 11               62.97               10.36                5.02
#
#     LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 11                6.32           10.7     34.36665
#
# [1 rows x 78 columns]

# %% [markdown]
# #### Filtering by `RecordID`.

# %%
df.isd.filter_record_ids([772])
# Out:
#     LocationID    SessionID GroupID  RecordID Language  Lockdown  \
# 36  TateModern  TateModern3   TM325     772.0  English         0
#
#             start_time            end_time   latitude  longitude  ...  \
# 36 2019-05-24 12:30:00 2019-05-24 12:35:00  51.508444  -0.099866  ...
#
#     FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 36               0.0644               0.437                    0.851
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 36            79.34               74.18               11.73
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 36                1.43                8.38           16.6    32.011822
#
# [1 rows x 78 columns]

# %% [markdown]
# #### Filtering by `Lockdown`.

# %%
df.isd.filter_lockdown(True)
#or
#df.isd.filter_lockdown()
# Out:
#       LocationID      SessionID GroupID  RecordID Language  Lockdown  \
# 10     EustonTap     EustonTap4   ET401       NaN      NaN         1
# 11     EustonTap     EustonTap4   ET402       NaN      NaN         1
# 12     EustonTap     EustonTap4   ET403       NaN      NaN         1
# 13     EustonTap     EustonTap4   ET404       NaN      NaN         1
# 14     EustonTap     EustonTap4   ET405       NaN      NaN         1
# 15     EustonTap     EustonTap4   ET406       NaN      NaN         1
# 16     EustonTap     EustonTap4   ET407       NaN      NaN         1
# 17     EustonTap     EustonTap4   ET408       NaN      NaN         1
# 18     EustonTap     EustonTap4   ET409       NaN      NaN         1
# 19     EustonTap     EustonTap4   ET410       NaN      NaN         1
# 20  TorringtonSq  TorringtonSq5   TS532       NaN      NaN         1
# 21  TorringtonSq  TorringtonSq5   TS533       NaN      NaN         1
# 22  TorringtonSq  TorringtonSq5   TS534       NaN      NaN         1
# 23  TorringtonSq  TorringtonSq5   TS535       NaN      NaN         1
# 24  TorringtonSq  TorringtonSq5   TS536       NaN      NaN         1
# 25  TorringtonSq  TorringtonSq5   TS537       NaN      NaN         1
# 26  TorringtonSq  TorringtonSq5   TS538       NaN      NaN         1
# 27  TorringtonSq  TorringtonSq5   TS539       NaN      NaN         1
# 28  TorringtonSq  TorringtonSq5   TS540       NaN      NaN         1
# 29  TorringtonSq  TorringtonSq5   TS541       NaN      NaN         1
#
#    start_time end_time  latitude  longitude  ...  FS_Avg,arith(vacil)  \
# 10        NaT      NaT       NaN        NaN  ...              0.00524
# 11        NaT      NaT       NaN        NaN  ...              0.00484
# 12        NaT      NaT       NaN        NaN  ...              0.00417
# 13        NaT      NaT       NaN        NaN  ...              0.00532
# 14        NaT      NaT       NaN        NaN  ...              0.00449
# 15        NaT      NaT       NaN        NaN  ...              0.00717
# 16        NaT      NaT       NaN        NaN  ...              0.00481
# 17        NaT      NaT       NaN        NaN  ...              0.00364
# 18        NaT      NaT       NaN        NaN  ...              0.00537
# 19        NaT      NaT       NaN        NaN  ...              0.00449
# 20        NaT      NaT       NaN        NaN  ...              0.00902
# 21        NaT      NaT       NaN        NaN  ...              0.00560
# 22        NaT      NaT       NaN        NaN  ...              0.00375
# 23        NaT      NaT       NaN        NaN  ...              0.01190
# 24        NaT      NaT       NaN        NaN  ...              0.01080
# 25        NaT      NaT       NaN        NaN  ...              0.00550
# 26        NaT      NaT       NaN        NaN  ...              0.00916
# 27        NaT      NaT       NaN        NaN  ...              0.00967
# 28        NaT      NaT       NaN        NaN  ...              0.00902
# 29        NaT      NaT       NaN        NaN  ...              0.00930
#
#     I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  LZeq_L(dB(SPL))  \
# 10               0.333                   0.1150            76.84
# 11               0.335                   0.1260            69.57
# 12               0.310                   0.1190            75.83
# 13               0.293                   0.1590            71.32
# 14               0.308                   0.1250            75.01
# 15               0.330                   0.2300            79.31
# 16               0.316                   0.1650            77.07
# 17               0.311                   0.0649            69.48
# 18               0.315                   0.1720            78.22
# 19               0.284                   0.3590            76.49
# 20               0.320                   0.3280            67.18
# 21               0.351                   0.1170            70.54
# 22               0.418                   0.0960            68.70
# 23               0.466                   0.2390            71.71
# 24               0.509                   0.2160            79.78
# 25               0.399                   0.2030            71.77
# 26               0.359                   0.2300            68.85
# 27               0.363                   0.4810            79.33
# 28               0.445                   0.2570            67.57
# 29               0.404                   0.2460            78.01
#
#     LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  LCeq_LAeq(dB(SPL))  \
# 10               69.23                6.23                6.68
# 11               62.97               10.36                5.02
# 12               66.83                8.26                5.84
# 13               58.56                2.64               10.71
# 14               66.89                3.93                6.34
# 15               59.79                4.39               13.60
# 16               68.41                6.58                6.89
# 17               59.59                7.24                7.70
# 18               69.98               16.48                6.16
# 19               64.31               13.06               10.50
# 20               55.15                5.12                8.39
# 21               57.12               11.36                9.88
# 22               57.04               10.80                7.96
# 23               60.35               10.31                8.38
# 24               55.54                8.41               16.14
# 25               52.90                5.61               12.97
# 26               56.30               10.09                9.27
# 27               64.32               14.80               13.95
# 28               49.33                2.64               12.12
# 29               59.17               16.54               14.17
#
#     LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 10                5.51          12.60    41.381249
# 11                6.32          10.70    34.366650
# 12                7.11          12.10    34.366650
# 13                3.45          11.20    34.366650
# 14                3.77          12.40    38.822900
# 15                7.84          13.30          NaN
# 16                5.25          12.90          NaN
# 17                4.17          10.80    38.846366
# 18               12.28          12.50    38.846366
# 19               11.12          11.30    37.989434
# 20                4.26           8.97    37.989434
# 21               11.43          10.20    27.090436
# 22               10.54           9.97          NaN
# 23                7.81          10.70          NaN
# 24               10.92          12.80    46.548897
# 25                8.31          10.80    46.548897
# 26                8.16           9.99    36.548457
# 27               20.39          10.90    36.548457
# 28                5.04           9.62          NaN
# 29               17.02          11.10          NaN
#
# [20 rows x 78 columns]

# %% [markdown]
# However, if more complex filters or some other custom filter is needed, `pandas` provides a very nice approach with its `query()` method.
#
# For instance, if we wanted to filter by `gender`:

# %%
df.query("Gender == 'Female'")
# Out:
#            LocationID           SessionID GroupID  RecordID Language  \
# 1          CamdenTown         CamdenTown1   CT101     561.0  English
# 6          CamdenTown         CamdenTown1   CT105     555.0  English
# 7          CamdenTown         CamdenTown1   CT105     529.0  English
# 32         TateModern         TateModern3   TM323     777.0  English
# 33         TateModern         TateModern3   TM324     773.0  English
# 34         TateModern         TateModern3   TM324     749.0  English
# 35         TateModern         TateModern3   TM325     767.0  English
# 37         TateModern         TateModern3   TM326     771.0  English
# 38         TateModern         TateModern3   TM327     751.0  English
# 39         TateModern         TateModern3   TM328     752.0  English
# 40  RegentsParkFields  RegentsParkFields1   RF116     815.0  English
# 41  RegentsParkFields  RegentsParkFields1   RF116     816.0  English
# 42  RegentsParkFields  RegentsParkFields1   RF116     814.0  English
# 43  RegentsParkFields  RegentsParkFields1   RF117     818.0  English
# 45  RegentsParkFields  RegentsParkFields1   RF118     819.0  English
# 48  RegentsParkFields  RegentsParkFields1   RF120     821.0  English
# 49  RegentsParkFields  RegentsParkFields1   RF121     823.0  English
#
#     Lockdown          start_time            end_time   latitude  longitude  \
# 1          0 2019-05-02 11:40:00 2019-05-02 11:43:00  51.539124  -0.142624
# 6          0 2019-05-02 11:56:00 2019-05-02 12:09:00  51.539124  -0.142624
# 7          0 2019-05-02 11:56:00 2019-05-02 12:09:00  51.539124  -0.142624
# 32         0 2019-05-24 12:18:00 2019-05-24 12:23:00  51.508444  -0.099866
# 33         0 2019-05-24 12:24:00 2019-05-24 12:39:00  51.508444  -0.099866
# 34         0 2019-05-24 12:20:00 2019-05-24 12:22:00  51.508483  -0.099884
# 35         0 2019-05-24 12:30:00 2019-05-24 12:37:00  51.508444  -0.099866
# 37         0 2019-05-24 17:43:00 2019-05-24 12:46:00  51.508444  -0.099866
# 38         0 2019-05-24 12:47:00 2019-05-24 12:51:00  51.508409  -0.099869
# 39         0 2019-05-24 12:50:00 2019-05-24 12:55:00  51.508531  -0.099814
# 40         0 2019-05-31 12:22:00 2019-05-31 12:26:00  51.532535  -0.146275
# 41         0 2019-05-31 12:24:00 2019-05-31 12:26:00  51.530675  -0.149612
# 42         0 2019-05-31 11:22:00 2019-05-31 11:26:00  51.532535  -0.146275
# 43         0 2019-05-31 11:26:00 2019-05-31 11:30:00  51.530492  -0.146047
# 45         0 2019-05-31 11:32:00 2019-05-31 11:35:00  51.532535  -0.146275
# 48         0 2019-05-31 11:28:00 2019-05-31 11:37:00  51.532535  -0.146275
# 49         0 2019-05-31 11:38:00 2019-05-31 11:39:00  51.532535  -0.146275
#
#     ...  FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 1   ...               0.0170               0.358                   0.3090
# 6   ...                  NaN                 NaN                      NaN
# 7   ...                  NaN                 NaN                      NaN
# 32  ...                  NaN                 NaN                      NaN
# 33  ...                  NaN                 NaN                      NaN
# 34  ...                  NaN                 NaN                      NaN
# 35  ...               0.0644               0.437                   0.8510
# 37  ...               0.0233               0.406                   0.2510
# 38  ...               0.0171               0.482                   0.3510
# 39  ...               0.0429               0.439                   0.2870
# 40  ...               0.0165               0.439                   0.1210
# 41  ...               0.0165               0.439                   0.1210
# 42  ...               0.0165               0.439                   0.1210
# 43  ...               0.0141               0.427                   0.1270
# 45  ...               0.0227               0.495                   0.0940
# 48  ...               0.0272               0.413                   0.0957
# 49  ...               0.0340               0.420                   0.1360
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 1             79.72               70.07                7.78
# 6               NaN                 NaN                 NaN
# 7               NaN                 NaN                 NaN
# 32              NaN                 NaN                 NaN
# 33              NaN                 NaN                 NaN
# 34              NaN                 NaN                 NaN
# 35            79.34               74.18               11.73
# 37            73.51               62.61                5.64
# 38            77.64               63.79                5.11
# 39            73.59               64.11                7.89
# 40            79.93               66.07                5.27
# 41            79.93               66.07                5.27
# 42            79.93               66.07                5.27
# 43            76.38               63.10                5.53
# 45            65.12               51.21                4.44
# 48            73.82               54.54                9.07
# 49            71.75               55.87                8.21
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 1                 7.81                8.11           14.3    36.019181
# 6                  NaN                 NaN            NaN          NaN
# 7                  NaN                 NaN            NaN          NaN
# 32                 NaN                 NaN            NaN    35.780862
# 33                 NaN                 NaN            NaN    48.207210
# 34                 NaN                 NaN            NaN    40.585995
# 35                1.43                8.38           16.6    32.011822
# 37                9.46                3.19           13.3    30.767981
# 38               11.46                3.63           13.8    30.767981
# 39                6.50                4.23           14.2    49.281216
# 40                9.44                3.49           13.3    49.281216
# 41                9.44                3.49           13.3    33.313603
# 42                9.44                3.49           13.3    33.313603
# 43                9.82                3.25           13.1          NaN
# 45                9.78                3.96           10.8    35.027791
# 48               11.98                5.70           10.9          NaN
# 49                9.66                8.91           12.3   100.494469
#
# [17 rows x 78 columns]

# %% [markdown]
# For instance, if we wanted to filter by `ISOPleasant`:

# %%
df.query("ISOPleasant == 1")
# Out:
#            LocationID           SessionID GroupID  RecordID Language  \
# 32         TateModern         TateModern3   TM323     777.0  English
# 43  RegentsParkFields  RegentsParkFields1   RF117     818.0  English
#
#     Lockdown          start_time            end_time   latitude  longitude  \
# 32         0 2019-05-24 12:18:00 2019-05-24 12:23:00  51.508444  -0.099866
# 43         0 2019-05-31 11:26:00 2019-05-31 11:30:00  51.530492  -0.146047
#
#     ...  FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 32  ...                  NaN                 NaN                      NaN
# 43  ...               0.0141               0.427                    0.127
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 32              NaN                 NaN                 NaN
# 43            76.38                63.1                5.53
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 32                 NaN                 NaN            NaN    35.780862
# 43                9.82                3.25           13.1          NaN
#
# [2 rows x 78 columns]

# %% [markdown]
# Or a more complex filter like women over 50:

# %%
df.query("Gender == 'Female' and Age > 50")
# Out:
#            LocationID           SessionID GroupID  RecordID Language  \
# 32         TateModern         TateModern3   TM323     777.0  English
# 33         TateModern         TateModern3   TM324     773.0  English
# 35         TateModern         TateModern3   TM325     767.0  English
# 40  RegentsParkFields  RegentsParkFields1   RF116     815.0  English
# 43  RegentsParkFields  RegentsParkFields1   RF117     818.0  English
#
#     Lockdown          start_time            end_time   latitude  longitude  \
# 32         0 2019-05-24 12:18:00 2019-05-24 12:23:00  51.508444  -0.099866
# 33         0 2019-05-24 12:24:00 2019-05-24 12:39:00  51.508444  -0.099866
# 35         0 2019-05-24 12:30:00 2019-05-24 12:37:00  51.508444  -0.099866
# 40         0 2019-05-31 12:22:00 2019-05-31 12:26:00  51.532535  -0.146275
# 43         0 2019-05-31 11:26:00 2019-05-31 11:30:00  51.530492  -0.146047
#
#     ...  FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 32  ...                  NaN                 NaN                      NaN
# 33  ...                  NaN                 NaN                      NaN
# 35  ...               0.0644               0.437                    0.851
# 40  ...               0.0165               0.439                    0.121
# 43  ...               0.0141               0.427                    0.127
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 32              NaN                 NaN                 NaN
# 33              NaN                 NaN                 NaN
# 35            79.34               74.18               11.73
# 40            79.93               66.07                5.27
# 43            76.38               63.10                5.53
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 32                 NaN                 NaN            NaN    35.780862
# 33                 NaN                 NaN            NaN    48.207210
# 35                1.43                8.38           16.6    32.011822
# 40                9.44                3.49           13.3    49.281216
# 43                9.82                3.25           13.1          NaN
#
# [5 rows x 78 columns]

# %% [markdown]
# Or a more complex filter like women wiht pleasent < 3:

# %%
df.query("Gender == 'Female' and pleasant < 3")
# Out:
#            LocationID           SessionID GroupID  RecordID Language  \
# 41  RegentsParkFields  RegentsParkFields1   RF116     816.0  English
# 42  RegentsParkFields  RegentsParkFields1   RF116     814.0  English
#
#     Lockdown          start_time            end_time   latitude  longitude  \
# 41         0 2019-05-31 12:24:00 2019-05-31 12:26:00  51.530675  -0.149612
# 42         0 2019-05-31 11:22:00 2019-05-31 11:26:00  51.532535  -0.146275
#
#     ...  FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 41  ...               0.0165               0.439                    0.121
# 42  ...               0.0165               0.439                    0.121
#
#     LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 41            79.93               66.07                5.27
# 42            79.93               66.07                5.27
#
#     LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 41                9.44                3.49           13.3    33.313603
# 42                9.44                3.49           13.3    33.313603
#
# [2 rows x 78 columns]

# %% [markdown]
# All of these filters can also be chained together.

# %%
df.isd.filter_location_ids(['CamdenTown']).query("Gender == 'Male' and Age > 50")
#or
#df.query("Gender == 'Male' and Age > 50 and LocationID == 'CamdenTown'")
# Out:
#    LocationID    SessionID GroupID  RecordID Language  Lockdown  \
# 4  CamdenTown  CamdenTown1   CT103     527.0  English         0
# 9  CamdenTown  CamdenTown1   CT107     559.0  English         0
#
#            start_time            end_time   latitude  longitude  ...  \
# 4 2019-05-02 11:49:00 2019-05-02 11:54:00  51.539124  -0.142624  ...
# 9 2019-05-02 12:20:00 2019-05-02 12:25:00  51.539124  -0.142624  ...
#
#    FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 4              0.00889               0.370                    0.193
# 9              0.02470               0.426                    0.293
#
#    LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 4            76.79               66.71                4.23
# 9            78.52               68.32                8.55
#
#    LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 4                7.61                3.99           13.4    27.108635
# 9                8.00                5.60           14.8    32.959376
#
# [2 rows x 78 columns]

# %% [markdown]
# <h1 style="color:#AED6F1 ; font-weight: bold; font-style: italic;">Plotting</h1>
#
# Probably the most important part of the `Soundscapy` package is its methods for plotting soundscape circumplex data. Making use of the `seaborn kdeplot()`, we can visualise the distribution of responses within the soundscape circumplex.
#
# <h2 style="color:#FFA500 ; font-weight: bold; font-style: italic;">1) Scatter Plots</h2>
#
# The most basic plot is the `circumplex_scatter()`.
#
# First, we filter down to one location that we want to look at. Then, using the `circumplex_scatter()`, we can create a default formatted plot:

# %%
df.isd.filter_location_ids(['CamdenTown']).sspy.scatter()
# Out:
# C:\Users\fspintern1\AppData\Roaming\Python\Python311\site-packages\soundscapy\plotting\circumplex.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   s = sns.scatterplot(
# <Axes: title={'center': 'Soundscape Scatter Plot'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# Each point in this scatter plot represents the ISOCoordinate values of one survey taken in Russell Square during all of the sessions.
#
# We can see that the `circumplex_scatter()` has added some customisations on top of the underlying `seaborn` plots. The first is to automatically scale the plot area to the -1 to +1 bounding of the circumplex. Second is the inclusion of a grid highlighting the typically quadrants of the circumplex. Finally, customised labels which make the relationship of the ISOPleasant and ISOEventful values more clear.
#
# This plot can be further customised though. For instance, if you don't like or need those custom primary labels, we can remove them by setting `prim_labels = False`. We could also add labels for the diagonal circumplex axes with `diagonal_lines = True`.

# %%
#prim_labels = False
#df.isd.filter_location_ids(['CamdenTown']).sspy.scatter( diagonal_lines=True)

df.isd.filter_location_ids(['CamdenTown']).sspy.scatter( figsize=(8, 8), diagonal_lines=True)
# Out:
# C:\Users\fspintern1\AppData\Roaming\Python\Python311\site-packages\soundscapy\plotting\circumplex.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   s = sns.scatterplot(
# <Axes: title={'center': 'Soundscape Scatter Plot'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# ## Scatter Parameters
#
#     data=None,
#     x="ISOPleasant",
#     y="ISOEventful",
#     title="Soundscape Scatter Plot",
#     diagonal_lines=False,
#     xlim=(-1, 1),
#     ylim=(-1, 1),
#     figsize=(5, 5),
#     legend_loc="lower left",
#     hue=None,
#     style=None,
#     s=20,
#     palette="colorblind",
#     hue_order=None,
#     hue_norm=None,
#     sizes=None,
#     size_order=None,
#     size_norm=None,
#     markers=True,
#     style_order=None,
#     alpha=None,
#     legend="auto",
#     ax=None,
#     **scatter_kws,

# %% [markdown]
# It's also often very useful to plot the different sessions with different colours. This is done with the `hue` parameter. At the same time, we'll also add a legend and make the scatter points larger.

# %%
df.isd.filter_lockdown().sspy.scatter(hue='SessionID', legend=True, s=20, title='All Sessions')
# Out:
# <Axes: title={'center': 'All Sessions'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# <h2 style="color:#FFA500 ; font-weight: bold; font-style: italic;">2) Distribution Plots</h2>
#
# The real power of `Soundscapy` is in creating plots of the distribution of soundscape assessments. The interface for doing this is the same as the scatter plots above.

# %%
df.isd.filter_location_ids(['CamdenTown']).sspy.density()
# Out:
# C:\Users\fspintern1\AppData\Roaming\Python\Python311\site-packages\soundscapy\plotting\circumplex.py:297: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   d = sns.scatterplot(
# C:\Users\fspintern1\AppData\Roaming\Python\Python311\site-packages\soundscapy\plotting\circumplex.py:343: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   d = sns.kdeplot(
# <Axes: title={'center': 'Soundscapy Density Plot'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# This can be customised in the same ways as the scatter plots. To see how the scatter points and the density heatmap are related, we can add scatter points to the density plot.

# %%
df.isd.filter_location_ids('CamdenTown').sspy.density(incl_scatter=True, alpha=0.75, hue="LocationID")
# Out:
# <Axes: title={'center': 'Soundscapy Density Plot'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# *How to analyse* proposes a method for simplifying this plot, allowing easy comparison between multiple soundscapes. In the simplified version, rather than showing the full distribution heatmap, we plot only the 50th percentile density curve, showing the general shape of the soundscape.
#
# This is done by digging into `seaborn` `kdeplot()` and using its parameters `thresh` and `levels`. We'll also go ahead and customise some other aspects, such as the color palette.

# %%
df.isd.filter_location_ids(['CamdenTown']).sspy.density(
    title="Median perception contour and scatter plot of individual assessments\n\n",
    density_type="simple", # Instead of full density type
    hue="LocationID",
    legend=True,
    #palette="dark:gray",
)
# Out:
# <Axes: title={'center': 'Median perception contour and scatter plot of individual assessments\n\n'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# As we said, this is particularly useful for comparing different soundscapes. So let's see how we can plot three different soundscapes at once.

# %%
df.isd.filter_location_ids(
    ["CamdenTown", "TateModern", "RegentsParkFields"]
).sspy.density(
    title="Comparison of the soundscapes of three urban spaces\n\n",
    hue="LocationID",
    density_type="simple",
    incl_scatter=True,
    #palette="husl",
)
# Out:
# <Axes: title={'center': 'Comparison of the soundscapes of three urban spaces\n\n'}, xlabel='ISOPleasant', ylabel='ISOEventful'>

# %% [markdown]
# <h2 style="color:#FFA500 ; font-weight: bold; font-style: italic;">3) Jointplot</h2>

# %%
df.isd.filter_location_ids(["CamdenTown", "TateModern"]).sspy.jointplot(hue="LocationID", marginal_kind="kde", density_type="full")
df.isd.filter_location_ids(["CamdenTown", "TateModern"]).sspy.jointplot(hue="LocationID", diagonal_lines=True,)

# %% [markdown]
# ## The current ISO 12913 framework
#
#
# Although different methods are proposed for data collection in ISO12913 Part 2, in the context of this study we focus on the questionnaire-based soundscape assessment (Method A), because it is underpinned by a theoretical relationship among the items of the questionnaire that compose it. The core of this questionnaire is the 8 perceptual attributes (PA) originally derived in Axlesson et al. (2010): pleasant, vibrant (or exciting), eventful, chaotic, annoying, monotonous, uneventful, and calm. In the questionnaire procedure, these PAs are assessed independently of each other, however, they are conceptually considered to form a two-dimensional circumplex with *Pleasantness* and *Eventfulness* on the x- and y-axis, respectively, where all regions of the space are equally likely to accomodate a given soundscape assessment. In Axelsson et al. (2010) a third primary dimension, *Familiarity* was also found, however this only accounted for 8% of the variance and is typically disregarded as part of the standard circumplex. As will be made clear throughout, the circumplex model has several aspects which make it useful for representing the soundscape perception of a space as a whole.
#
# ### Coordinate transformation
#
# To facilitate the analysis of the perceptual attribute (PA) responses, the Likert scale responses are coded from 1 (Strongly disagree) to 5 (Strongly agree) as ordinal variables. In order to reduce the 8 PA values into a pair of coordinates which can be plotted on the Pleasant-Eventful axes, Part 3 of the ISO 12913 provides a trigonometric transformation, based on the $45\degree$ relationship between the diagonal axes and the pleasant and eventful axes. This tranformation projects the coded values from the individual PAs down onto the primary Pleasantness and Eventfulness dimensions, then adds them together to form a single coordinate pair. In theory, this coordinate pair then encapsulates information from all 8 PA dimensions onto a more easily understandable and analyzable 2 dimensions.
#
# The ISO coordinates are thus calculated by:
#
# $$
# ISOPleasant = [(pleasant - annoying) + \cos{45\degree} * (calm - chaotic) + \cos{45\degree} * (vibrant - monotonous)] * \frac{1}{(4 + \sqrt{32})}
# $$
#
# $$
# ISOEventful = [(eventful - uneventful) + \cos{45\degree} * (chaotic - calm) + \cos{45\degree} * (vibrant - monotonous)] * \frac{1}{(4 + \sqrt{32})}
# $$
#
# where the PAs are arranged around the circumplex as shown in Figure 1. The $\cos{45\degree}$ term operates to project the diagonal terms down ono the x and y axes, and the $\frac{1}{4 + \sqrt{32}}$ scales the resulting coordinates to the range (-1, 1). The result of this transformation is demonstrated in Figure 1.
#
# To give an example of this, we create two example survey responses, with different PAQ answers:

# %%
sample_transform = {
    "RecordID": ["EX1", "EX2"],
    "pleasant": [4, 2],
    "vibrant": [4, 3],
    "eventful": [4, 5],
    "chaotic": [2, 5],
    "annoying": [1, 5],
    "monotonous": [3, 5],
    "uneventful": [3, 3],
    "calm": [4, 1],
}
sample_transform = pd.DataFrame().from_dict(sample_transform)
#sample_transform = sample_transform.sspy.convert_column_to_index("RecordID")
sample_transform
# Out:
#   RecordID  pleasant  vibrant  eventful  chaotic  annoying  monotonous  \
# 0      EX1         4        4         4        2         1           3
# 1      EX2         2        3         5        5         5           5
#
#    uneventful  calm
# 0           3     4
# 1           3     1

# %% [markdown]
# We can visualise how these individual PAQ answers are arranged on the circumplex with a radar plot.

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(4, 4))
plt.rcParams["figure.dpi"] = 350
#sample_transform.sspy.paq_radar()

# %% [markdown]
# Now, we can apply the transform formula from above to calculate the ISOPleasant and ISOEventful values and add them to the dataframe.

# %%
sample_transform = soundscapy.surveys.rename_paqs(sample_transform)
sample_transform = sample_transform.sspy.add_paq_coords(scale_to_one=True)
sample_transform
# Out:
#   RecordID  PAQ1  PAQ2  PAQ3  PAQ4  PAQ5  PAQ6  PAQ7  PAQ8  ISOPleasant  \
# 0      EX1     4     4     4     2     1     3     3     4      0.53033
# 1      EX2     2     3     5     5     5     5     3     1     -0.75000
#
#    ISOEventful
# 0     0.030330
# 1     0.353553
